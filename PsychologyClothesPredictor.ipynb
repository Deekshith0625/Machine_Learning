# %% [markdown]
# <a href="https://colab.research.google.com/github/Deekshith0625/Machine_Learning/blob/main/PsychologyClothesPredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("this is a new project")
# Out:
# this is a new project

# %%
print("new commit")
# Out:
# new commit
